# %%
import numpy as np
import pandas as pd

# %%
# Create array
marks=np.array([77,67,87,90,56,45,67,88,97])

# %%
print("Original marks:",marks)
# Out:
# Original marks: [77 67 87 90 56 45 67 88 97]

# %%
marks.ndim
# Out:
# 1

# %%
marks.shape
# Out:
# (9,)

# %%
marks.size
# Out:
# 9

# %%
marks.itemsize
# Out:
# 8

# %%
marks[0]
# Out:
# np.int64(77)

# %%
print("First five students marks :",marks[:5])
# Out:
# First five students marks : [77 67 87 90 56]

# %%
percentage=marks/100 *100

# %%
percentage
# Out:
# array([77., 67., 87., 90., 56., 45., 67., 88., 97.])

# %%
np.sum(marks)
# Out:
# np.int64(674)

# %%
failed=marks[marks<35]

# %%
failed
# Out:
# array([], dtype=int64)

# %%
Topper=marks[marks>90]

# %%
Topper
# Out:
# array([97])

# %%
np.argmax(marks) # --> Highest Position
# Out:
# np.int64(8)

# %%
import matplotlib.pyplot as plt

# %%
months=["jan","feb","march"]
sales=[77,76,87]

plt.plot(months,sales)

# %%
students=["abc","xyz","pqr"]
marks=[90,78,68]
